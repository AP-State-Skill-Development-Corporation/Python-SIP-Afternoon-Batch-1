# %% [markdown]
# **Pandas**
# - data manupulation
# - data analysis
# - data-load
# - data prepare
# - data-model

# %% [markdown]
# **Use cases**
# - Data cleaning
# - Data Transformation
# - Data Analysis

# %% [markdown]
# **Data Structures**
# - Series
# - DataFrame

# %% [markdown]
# Advantages of pandas
# - Easily handles missing data
# - Series for one-dimensional DataStructure
# - Data Frame is used for Multi Dimentional datasturucture
# - It provides efficient way to slice the data
# - It provides a flexiable way to merge or concate the tables
# - Homogenous

# %%
import pandas as pd

# %%
a=pd.Series([1,2,3,9,4,5,69])

# %%
a[3:6]
# Out:
# 3    9
# 4    4
# 5    5
# dtype: int64

# %% [markdown]
# **DataFrame**

# %%
df=pd.DataFrame([[1,2,3],[4,5,6]]) # Contains with row and columns
df
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6

# %%
df=pd.DataFrame([[1,2,3],[4,5,6]],columns=["ravi","ayyappa","surya"])

# %%
df
# Out:
#    ravi  ayyappa  surya
# 0     1        2      3
# 1     4        5      6

# %%
df=pd.read_csv("income.csv")
df.head(2)
# Out:
#   Index    State    Y2002    Y2003    Y2004    Y2005    Y2006    Y2007  \
# 0     A  Alabama  1296530  1317711  1118631  1492583  1107408  1440134
# 1     A   Alaska  1170302  1960378  1818085  1447852  1861639  1465841
#
#      Y2008    Y2009    Y2010    Y2011    Y2012    Y2013    Y2014    Y2015
# 0  1945229  1944173  1237582  1440756  1186741  1852841  1558906  1916661
# 1  1551826  1436541  1629616  1230866  1512804  1985302  1580394  1979143

# %%
df.tail(2)
# Out:
#    Index      State    Y2002    Y2003    Y2004    Y2005    Y2006    Y2007  \
# 49     W  Wisconsin  1788920  1518578  1289663  1436888  1251678  1721874
# 50     W    Wyoming  1775190  1498098  1198212  1881688  1750527  1523124
#
#       Y2008    Y2009    Y2010    Y2011    Y2012    Y2013    Y2014    Y2015
# 49  1980167  1901394  1648755  1940943  1729177  1510119  1701650  1846238
# 50  1587602  1504455  1282142  1881814  1673668  1994022  1204029  1853858

# %%
df["Y2002"]
# Out:
# 0     1296530
# 1     1170302
# 2     1742027
# 3     1485531
# 4     1685349
# 5     1343824
# 6     1610512
# 7     1330403
# 8     1111437
# 9     1964626
# 10    1929009
# 11    1461570
# 12    1353210
# 13    1508356
# 14    1776918
# 15    1499269
# 16    1509054
# 17    1813878
# 18    1584734
# 19    1582720
# 20    1579713
# 21    1647582
# 22    1295635
# 23    1729921
# 24    1983285
# 25    1221316
# 26    1877154
# 27    1885081
# 28    1426117
# 29    1419776
# 30    1605532
# 31    1819239
# 32    1395149
# 33    1616742
# 34    1618807
# 35    1802132
# 36    1173918
# 37    1794912
# 38    1320191
# 39    1501744
# 40    1631522
# 41    1159037
# 42    1811867
# 43    1520591
# 44    1771096
# 45    1146902
# 46    1134317
# 47    1977749
# 48    1677347
# 49    1788920
# 50    1775190
# Name: Y2002, dtype: int64

# %%
df.shape
# Out:
# (51, 16)

# %%
df
# Out:
#    Index                 State    Y2002    Y2003    Y2004    Y2005    Y2006  \
# 0      A               Alabama  1296530  1317711  1118631  1492583  1107408
# 1      A                Alaska  1170302  1960378  1818085  1447852  1861639
# 2      A               Arizona  1742027  1968140  1377583  1782199  1102568
# 3      A              Arkansas  1485531  1994927  1119299  1947979  1669191
# 4      C            California  1685349  1675807  1889570  1480280  1735069
# 5      C              Colorado  1343824  1878473  1886149  1236697  1871471
# 6      C           Connecticut  1610512  1232844  1181949  1518933  1841266
# 7      D              Delaware  1330403  1268673  1706751  1403759  1441351
# 8      D  District of Columbia  1111437  1993741  1374643  1827949  1803852
# 9      F               Florida  1964626  1468852  1419738  1362787  1339608
# 10     G               Georgia  1929009  1541565  1810773  1779091  1326846
# ...

# %%
df.head(4)
# Out:
#   Index     State    Y2002    Y2003    Y2004    Y2005    Y2006    Y2007  \
# 0     A   Alabama  1296530  1317711  1118631  1492583  1107408  1440134
# 1     A    Alaska  1170302  1960378  1818085  1447852  1861639  1465841
# 2     A   Arizona  1742027  1968140  1377583  1782199  1102568  1109382
# 3     A  Arkansas  1485531  1994927  1119299  1947979  1669191  1801213
#
#      Y2008    Y2009    Y2010    Y2011    Y2012    Y2013    Y2014    Y2015
# 0  1945229  1944173  1237582  1440756  1186741  1852841  1558906  1916661
# 1  1551826  1436541  1629616  1230866  1512804  1985302  1580394  1979143
# 2  1752886  1554330  1300521  1130709  1907284  1363279  1525866  1647724
# 3  1188104  1628980  1669295  1928238  1216675  1591896  1360959  1329341

# %%
df.set_index('Index',inplace=True)

# %%
df
# Out:
#                       State    Y2002    Y2003    Y2004    Y2005    Y2006  \
# Index
# A                   Alabama  1296530  1317711  1118631  1492583  1107408
# A                    Alaska  1170302  1960378  1818085  1447852  1861639
# A                   Arizona  1742027  1968140  1377583  1782199  1102568
# A                  Arkansas  1485531  1994927  1119299  1947979  1669191
# C                California  1685349  1675807  1889570  1480280  1735069
# C                  Colorado  1343824  1878473  1886149  1236697  1871471
# C               Connecticut  1610512  1232844  1181949  1518933  1841266
# D                  Delaware  1330403  1268673  1706751  1403759  1441351
# D      District of Columbia  1111437  1993741  1374643  1827949  1803852
# F                   Florida  1964626  1468852  1419738  1362787  1339608
# G                   Georgia  1929009  1541565  1810773  1779091  1326846
# H                    Hawaii  1461570  1200280  1213993  1245931  1459383
# ...

# %%
df.sort_values("Y2002",ascending=False)
# Out:
#                       State    Y2002    Y2003    Y2004    Y2005    Y2006  \
# Index
# M               Mississippi  1983285  1292558  1631325  1943311  1354579
# W                Washington  1977749  1687136  1199490  1163092  1334864
# F                   Florida  1964626  1468852  1419738  1362787  1339608
# G                   Georgia  1929009  1541565  1810773  1779091  1326846
# N                  Nebraska  1885081  1309769  1425527  1240465  1500594
# M                   Montana  1877154  1540099  1332722  1273327  1625721
# N                New Mexico  1819239  1226057  1935991  1124400  1723493
# K                  Kentucky  1813878  1448846  1800760  1250524  1137913
# T                 Tennessee  1811867  1485909  1974179  1157059  1786132
# O                      Ohio  1802132  1648498  1441386  1670280  1534888
# O                    Oregon  1794912  1726665  1805445  1133510  1502242
# W                 Wisconsin  1788920  1518578  1289663  1436888  1251678
# ...

# %%
df
# Out:
#                       State    Y2002    Y2003    Y2004    Y2005    Y2006  \
# Index
# A                   Alabama  1296530  1317711  1118631  1492583  1107408
# A                    Alaska  1170302  1960378  1818085  1447852  1861639
# A                   Arizona  1742027  1968140  1377583  1782199  1102568
# A                  Arkansas  1485531  1994927  1119299  1947979  1669191
# C                California  1685349  1675807  1889570  1480280  1735069
# C                  Colorado  1343824  1878473  1886149  1236697  1871471
# C               Connecticut  1610512  1232844  1181949  1518933  1841266
# D                  Delaware  1330403  1268673  1706751  1403759  1441351
# D      District of Columbia  1111437  1993741  1374643  1827949  1803852
# F                   Florida  1964626  1468852  1419738  1362787  1339608
# G                   Georgia  1929009  1541565  1810773  1779091  1326846
# H                    Hawaii  1461570  1200280  1213993  1245931  1459383
# ...

# %% [markdown]
# **iloc and loc**

# %%
df.head()
# Out:
#             State    Y2002    Y2003    Y2004    Y2005    Y2006    Y2007  \
# Index
# A         Alabama  1296530  1317711  1118631  1492583  1107408  1440134
# A          Alaska  1170302  1960378  1818085  1447852  1861639  1465841
# A         Arizona  1742027  1968140  1377583  1782199  1102568  1109382
# A        Arkansas  1485531  1994927  1119299  1947979  1669191  1801213
# C      California  1685349  1675807  1889570  1480280  1735069  1812546
#
#          Y2008    Y2009    Y2010    Y2011    Y2012    Y2013    Y2014    Y2015
# Index
# A      1945229  1944173  1237582  1440756  1186741  1852841  1558906  1916661
# A      1551826  1436541  1629616  1230866  1512804  1985302  1580394  1979143
# A      1752886  1554330  1300521  1130709  1907284  1363279  1525866  1647724
# A      1188104  1628980  1669295  1928238  1216675  1591896  1360959  1329341
# C      1487315  1663809  1624509  1639670  1921845  1156536  1388461  1644607

# %%
df.iloc[6]
# Out:
# State    Connecticut
# Y2002        1610512
# Y2003        1232844
# Y2004        1181949
# Y2005        1518933
# Y2006        1841266
# Y2007        1976976
# Y2008        1764457
# Y2009        1972730
# Y2010        1968730
# Y2011        1945524
# Y2012        1228529
# Y2013        1582249
# Y2014        1503156
# Y2015        1718072
# Name: C, dtype: object

# %%
df.loc["A":"C"]
# Out:
#              State    Y2002    Y2003    Y2004    Y2005    Y2006    Y2007  \
# Index
# A          Alabama  1296530  1317711  1118631  1492583  1107408  1440134
# A           Alaska  1170302  1960378  1818085  1447852  1861639  1465841
# A          Arizona  1742027  1968140  1377583  1782199  1102568  1109382
# A         Arkansas  1485531  1994927  1119299  1947979  1669191  1801213
# C       California  1685349  1675807  1889570  1480280  1735069  1812546
# C         Colorado  1343824  1878473  1886149  1236697  1871471  1814218
# C      Connecticut  1610512  1232844  1181949  1518933  1841266  1976976
#
#          Y2008    Y2009    Y2010    Y2011    Y2012    Y2013    Y2014    Y2015
# Index
# A      1945229  1944173  1237582  1440756  1186741  1852841  1558906  1916661
# A      1551826  1436541  1629616  1230866  1512804  1985302  1580394  1979143
# A      1752886  1554330  1300521  1130709  1907284  1363279  1525866  1647724
# ...

# %%
df.loc["A"]
# Out:
#           State    Y2002    Y2003    Y2004    Y2005    Y2006    Y2007  \
# Index
# A       Alabama  1296530  1317711  1118631  1492583  1107408  1440134
# A        Alaska  1170302  1960378  1818085  1447852  1861639  1465841
# A       Arizona  1742027  1968140  1377583  1782199  1102568  1109382
# A      Arkansas  1485531  1994927  1119299  1947979  1669191  1801213
#
#          Y2008    Y2009    Y2010    Y2011    Y2012    Y2013    Y2014    Y2015
# Index
# A      1945229  1944173  1237582  1440756  1186741  1852841  1558906  1916661
# A      1551826  1436541  1629616  1230866  1512804  1985302  1580394  1979143
# A      1752886  1554330  1300521  1130709  1907284  1363279  1525866  1647724
# A      1188104  1628980  1669295  1928238  1216675  1591896  1360959  1329341

# %% [markdown]
# **avg of 2002 data**

# %%
print(df.loc['A':'C'])
# Out:
#              State    Y2002    Y2003    Y2004    Y2005    Y2006    Y2007  \
# Index
# A          Alabama  1296530  1317711  1118631  1492583  1107408  1440134
# A           Alaska  1170302  1960378  1818085  1447852  1861639  1465841
# A          Arizona  1742027  1968140  1377583  1782199  1102568  1109382
# A         Arkansas  1485531  1994927  1119299  1947979  1669191  1801213
# C       California  1685349  1675807  1889570  1480280  1735069  1812546
# C         Colorado  1343824  1878473  1886149  1236697  1871471  1814218
# C      Connecticut  1610512  1232844  1181949  1518933  1841266  1976976
#
#          Y2008    Y2009    Y2010    Y2011    Y2012    Y2013    Y2014    Y2015
# Index
# A      1945229  1944173  1237582  1440756  1186741  1852841  1558906  1916661
# A      1551826  1436541  1629616  1230866  1512804  1985302  1580394  1979143
# A      1752886  1554330  1300521  1130709  1907284  1363279  1525866  1647724
# ...

# %%
sum(df["Y2002"])/len(df["Y2002"])
# Out:
# 1566034.1764705882

# %%
df.describe()
# Out:
#               Y2002         Y2003         Y2004         Y2005         Y2006  \
# count  5.100000e+01  5.100000e+01  5.100000e+01  5.100000e+01  5.100000e+01
# mean   1.566034e+06  1.509193e+06  1.540555e+06  1.522064e+06  1.530969e+06
# std    2.464425e+05  2.641092e+05  2.813872e+05  2.671748e+05  2.505603e+05
# min    1.111437e+06  1.110625e+06  1.118631e+06  1.122030e+06  1.102568e+06
# 25%    1.374180e+06  1.292390e+06  1.268292e+06  1.267340e+06  1.337236e+06
# 50%    1.584734e+06  1.485909e+06  1.522230e+06  1.480280e+06  1.531641e+06
# 75%    1.776054e+06  1.686698e+06  1.808109e+06  1.778170e+06  1.732259e+06
# max    1.983285e+06  1.994927e+06  1.979395e+06  1.990062e+06  1.985692e+06
#
#               Y2007         Y2008         Y2009         Y2010         Y2011  \
# count  5.100000e+01  5.100000e+01  5.100000e+01  5.100000e+01  5.100000e+01
# mean   1.553219e+06  1.538398e+06  1.658519e+06  1.504108e+06  1.574968e+06
# ...

# %%
print(dir(pd),end="")
# Out:
# ['Categorical', 'CategoricalDtype', 'CategoricalIndex', 'DataFrame', 'DateOffset', 'DatetimeIndex', 'DatetimeTZDtype', 'ExcelFile', 'ExcelWriter', 'Float64Index', 'Grouper', 'HDFStore', 'Index', 'IndexSlice', 'Int16Dtype', 'Int32Dtype', 'Int64Dtype', 'Int64Index', 'Int8Dtype', 'Interval', 'IntervalDtype', 'IntervalIndex', 'MultiIndex', 'NaT', 'Panel', 'Period', 'PeriodDtype', 'PeriodIndex', 'RangeIndex', 'Series', 'SparseArray', 'SparseDataFrame', 'SparseDtype', 'SparseSeries', 'TimeGrouper', 'Timedelta', 'TimedeltaIndex', 'Timestamp', 'UInt16Dtype', 'UInt32Dtype', 'UInt64Dtype', 'UInt64Index', 'UInt8Dtype', '__builtins__', '__cached__', '__doc__', '__docformat__', '__file__', '__git_version__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_hashtable', '_lib', '_libs', '_np_version_under1p13', '_np_version_under1p14', '_np_version_under1p15', '_np_version_under1p16', '_np_version_under1p17', '_tslib', '_version', 'api', 'array', 'arrays', 'bdate_ra
# ...

# %%
d1=pd.DataFrame([["m1",60],["m2",40]],columns=["sub","marks"])
d2=pd.DataFrame([["cse",40,80],["ece",60,90]],columns=["sub1","marks1","extracolo"])

# %%
d1
# Out:
#   sub  marks
# 0  m1     60
# 1  m2     40

# %%
d2
# Out:
#   sub1  marks1  extracolo
# 0  cse      40         80
# 1  ece      60         90

# %%
a=pd.concat([d1,d2],ignore_index=True)
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
pd.concat([d1,d2],axis=1)
# Out:
#   sub  marks sub1  marks1  extracolo
# 0  m1     60  cse      40         80
# 1  m2     40  ece      60         90

# %%
df.iloc[[6,9]]
# Out:
#              State    Y2002    Y2003    Y2004    Y2005    Y2006    Y2007  \
# Index
# C      Connecticut  1610512  1232844  1181949  1518933  1841266  1976976
# F          Florida  1964626  1468852  1419738  1362787  1339608  1278550
#
#          Y2008    Y2009    Y2010    Y2011    Y2012    Y2013    Y2014    Y2015
# Index
# C      1764457  1972730  1968730  1945524  1228529  1582249  1503156  1718072
# F      1756185  1818438  1198403  1497051  1131928  1107448  1407784  1170389
